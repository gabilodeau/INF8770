# %% [markdown]
# <a href="https://colab.research.google.com/github/gabilodeau/INF8770/blob/master/Incrustation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INF8770 Technologies multimédias
#
# Polytechnique Montréal
#
# Exemple d'incrustation

# %% [markdown]
# Exécuter les 2 lignes suivantes pour colab.

# %%
# !git clone https://github.com/gabilodeau/INF8770
# %cd INF8770
# Out:
# Cloning into 'INF8770'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 440 (delta 65), reused 27 (delta 8), pack-reused 295
# Receiving objects: 100% (440/440), 39.85 MiB | 30.22 MiB/s, done.
# Resolving deltas: 100% (219/219), done.
# /content/INF8770

# %%
import numpy as np
import matplotlib.pyplot as py

# %% [markdown]
# Lecture de l'image et affichage de celle-ci.

# %%
imagelue = py.imread('320px-Girl_in_front_of_a_green_background.jpg')
image=imagelue.astype('float')
py.imshow(imagelue)
py.show()

# %% [markdown]
# Application d'un algorithme d'incrustation

# %%
k0 = 1.4
k1 = 1.0
k2 = 40.0
Rouge = image[:,:,0]
Vert = image[:,:,1]
Bleu = image[:,:,2]

imagesortie = np.copy(image)

#Détection du vert
alpha = k0*Bleu-k1*Vert+k2;

#Application du masque
Rouge[alpha<=0] = 0
Vert[alpha<=0] = 0
Bleu[alpha<=0] = 0

imagesortie[:,:,0] = Rouge
imagesortie[:,:,1] = Vert
imagesortie[:,:,2] = Bleu

# %%
py.imshow(imagesortie.astype('uint8'))
py.show()
