# %% [markdown]
# <a href="https://colab.research.google.com/github/gabilodeau/INF8770/blob/master/ImageCommeSurface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INF8770 Technologies multimédias
#
# Polytechnique Montréal
#
# Image vue comme une surface 3D

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from PIL import Image as pil

# %% [markdown]
# Exécuter les 2 lignes suivantes pour colab.

# %%
# !git clone https://github.com/gabilodeau/INF8770
# %cd INF8770
# Out:
# fatal: destination path 'INF8770' already exists and is not an empty directory.
# /content/INF8770

# %%
fig1 = plt.figure(figsize = (5,5))
image = pil.open('RGB.jpg').convert('L')
image = image.resize((320, 200))
plt.imshow(image,cmap = plt.get_cmap('gray'))
plt.show()

# %%
#%matplotlib notebook #Fonctionne seulement avec jupyter notebook pour un graphique interactif
xx, yy = np.mgrid[0:image.height, 0:image.width]
pixels = np.array(image.getdata()).reshape((image.height, image.width))
fig2 = plt.figure(figsize = (10,10))
ax = fig2.add_subplot(projection='3d')
ax.view_init(40, 0)
ax.plot_surface(xx, yy, pixels ,rstride=1, cstride=1, cmap=plt.cm.gray,linewidth=0)
plt.show()
